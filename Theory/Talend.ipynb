# %% [markdown]
# Build a modern microservice architecture with Talend Cloud.
# Scalability and agility.
#
# is the tool which gives you the foundation to rapidly understand how things work and how things have to be structured it simply eliminates a big chunk of your risk while accelerating your development process
#
# Talend is not only a great tool for ETL but it also allows us to build a modern
# microservice based architecture for real-time integration and event-driven systems

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Quickly implement API service. Manage and operate by scale. Extendable architecture.
#
# 1) so first you would start with the <b>API designer</b>: visually build contract, to document it directly within the tool
#
# 2) Talend also provides a <b>test tool</b> which is incorporated into the talent Suite meaning it makes it easy for you to Mock and test your endpoints very quickly because it now knows your API already
#
# 3) last but not least you will use the <b>Talend Studio</b> a it's a visual user interface: Build Jobs and data services for integration. Output microservices and Docker Containers
#
# Job создаётся и тестируется в дев енв в Т-студио и потом publish to the cloud/workspace -->
#
# that ultimately puts us right into the <b>Talend Management console</b>

# %% [markdown]
# <b>Talend Managment Console</b> manages deployments
#
# login, select environments, pull up tasks
#
# ![image.png](attachment:image.png)
#
# <b>Talend Remote Engine </b> manages microservices : it is an agent which basically deploys, starts, stops and even observes your microservice (so you don't need operate using kubernetis - all can be done by Talend)

# %% [markdown]
# <b>API Designer</b> gui interface позволяет создать getters putters deletters etc from REST standart.
#
# Templates of components (Responces, Headers, Query Parameters) сохранются и их можно переиспользовать

# %% [markdown]
# <b>Talend Studio</b>
# ![image.png](attachment:image.png)

# %% [markdown]
# you can also embed it in almost any infrastructure and you can enhance it with other tools
#
# ![image.png](attachment:image.png)
#
# lets them easily scale up and down single microservices without dealing with the underlying Network infrastructure

# %% [markdown]
# Limitations
# At the time of this review, these are the limitations according to user feedback:
#
#  Isn’t resource optimized.
#
#  Doesn’t have sufficient documentation.
#
#  Isn’t cost-effective for smaller businesses and startups.
#
#  Doesn’t have the data integration module in the free version.
